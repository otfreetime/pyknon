# %%
from music21 import note, stream,environment, duration,converter,corpus
environment.set('musescoreDirectPNGPath', 'D:/MuseScore3/bin/MuseScore3.exe')

# %%
n1 = note.Note('C4')
n1.show()

# %%
n2 = note.Note('C5')
n2.show()

# %%
s=stream.Stream()
s.append(n1)
s.append(n2)
s.show()

# %%
s.write('midi',fp='midi/music21.midi')
# Out:
# 'midi/music21.midi'

# %%
n1.quarterLength
# Out:
# 1.0

# %%
n1 = note.Note('C4')
n1.quarterLength =.5
n1.show()

# %%
n1 = note.Note('C4')
n1.quarterLength =2
n1.show()

# %%
n1 = note.Note('C', quarterLength=4)
n1.show()

# %%
n1 = note.Note('C', quarterLength=1)
n2 = note.Note('E', quarterLength=.5)
n3 = note.Note('G', quarterLength=.5)
n4 = note.Note('C', quarterLength=2)

s=stream.Stream()
s.append([n1,n2,n3,n4])
s.write('midi',fp='midi/music21.midi')

s.show()
s.show('midi')
# Out:
#                 <div id='midiPlayerDiv1670'></div>
#                 <link rel="stylesheet" href="//cuthbertLab.github.io/music21j/css/m21.css"
#                     type="text/css" />
#                 <script>
#                 require.config({
#                     paths: {'music21': '//cuthbertLab.github.io/music21j/src/music21'}
#                 });
#                 require(['music21'], function() {
#                                mp = new music21.miditools.MidiPlayer();
#                                mp.addPlayer('#midiPlayerDiv1670');
#                                mp.base64Load('...');
#                         });
#                 </script>

# %%
converter.parse("tinynotation: 3/4 c4 d8 f g16 a g f#").show()

# %%
print (serial.rowToMatrix([2,1,9,10,5,3,4,0,8,7,6,11]) )
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5864/1281957926.py in <module>
# ----> 1 print (serial.rowToMatrix([2,1,9,10,5,3,4,0,8,7,6,11]) )
#
# NameError: name 'serial' is not defined

# %%
s = corpus.parse('bach/bwv65.2.xml')

# %%
s.analyze('key')
# Out:
# <music21.key.Key of a minor>

# %%
s.show()
